# %%
import pandas as pd

# %%
df = pd.read_csv('Iris (1).csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df2 = pd.read_excel('chisquare.xlsx')
df2.head()
# Out:
#        Unnamed: 0      Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 0             NaN  Observed Value        NaN         NaN        NaN
# 1  Color/ Species            Blue      Green         NaN        NaN
# 2          Setosa              34         16        50.0        NaN
# 3      Versicolor              32         18        50.0        NaN
# 4       Virginica              12         38        50.0        NaN
#
#   Unnamed: 5      Unnamed: 6      Unnamed: 7 Unnamed: 8  Unnamed: 9  \
# 0        NaN             NaN  Expected Value        NaN         NaN
# 1        NaN  Color/ Species            Blue      Green         NaN
# 2        NaN          Setosa              26         24         NaN
# 3        NaN      Versicolor              26         24         NaN
# 4        NaN       Virginica              26         24         NaN
#
#       Unnamed: 10 Unnamed: 11 Unnamed: 12  Unnamed: 13
# 0             NaN         NaN         NaN          NaN
# ...

# %%
df3 = pd.read_csv('Exploratory data analysis uses data.txt')
print(df3)
# Out:
#   Exploratory data analysis uses data visualisation techniques to draw inferences and obtain insights from the data. However  \
# 0  EDA also involves the preparation of data sets...
#
#     EDA is much more than plotting graphs or visualising data; it is about understanding and studying the given data in detail. Visualisation of data into plots/graphs can be considered one of the tools in the EDA process.
# 0                                                NaN

# %%
import pandas as pd

# Replace 'filename.json' with the actual file path
df4 = pd.read_json('jsonfilewithhierarchy-100.json')
df4.describe()
# Out:
#        totalFeed
# count      100.0
# mean       125.0
# std          0.0
# min        125.0
# 25%        125.0
# 50%        125.0
# 75%        125.0
# max        125.0

# %%
from PIL import Image;
image = Image.open('hXQAYC2tMyc28bTxzz6P-qpz8q7R8M4rAjBN.png')
image.show()

# %%
from PIL import Image;
image1=Image.open('hXQAYC2tMyc28bTxzz6P-qpz8q7R8M4rAjBN.png').resize((800, 600)).save('resized_image.png')

# %%
from IPython.display import Image

# Specify the path to the .png image file
image_path = 'hXQAYC2tMyc28bTxzz6P-qpz8q7R8M4rAjBN.png'  # Replace 'path_to_your_image.png' with the actual path

# Display the image in the notebook
Image(image_path)
